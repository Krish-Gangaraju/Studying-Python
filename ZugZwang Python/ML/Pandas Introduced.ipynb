# %%
import pandas as pd

# %%
# df means dataframe
df = pd.read_csv("/Users/kirangangaraju/Desktop/Python/ZugZwang/ML/CSVs/trial.csv")
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
df [::-1]    # To make it reversed
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
#
# ...

# %%
df.head()     #First Five
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df.head(7)     #First Seven
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
# 5       6    Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6       7     Balaji, L    2     IND  CSK+       Bowler      51      27
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# ...

# %%
df.tail()     #Last Five
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 125           0      0.00  ...  125.64       2       0     0    0.00  0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00  0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50  9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df.tail(7)      #Last Seven
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 123     124    Warner, DA    1     AUS     DD      Batsman     483       2
# 124     125     White, CL    2     AUS   RCB+      Batsman     146       5
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 123         876     85.79  ...  135.76      44       0     0    0.00   0.00
# 124        2037     80.48  ...  132.09      29      70     0    0.00  14.00
# 125           0      0.00  ...  125.64       2       0     0    0.00   0.00
# ...

# %%
df.shape    #Dimensions
# Out:
# (130, 26)

# %%
list(df.columns)
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
df['PLAYER NAME']   #Subsets for Columns
# Out:
# 0       Abdulla, YA
# 1      Abdur Razzak
# 2       Agarkar, AB
# 3         Ashwin, R
# 4      Badrinath, S
#            ...
# 125       Yadav, AS
# 126     Younis Khan
# 127    Yuvraj Singh
# 128     Zaheer Khan
# 129      Zoysa, DNT
# Name: PLAYER NAME, Length: 130, dtype: object

# %%
df[['PLAYER NAME','TEAM']]
# Out:
#       PLAYER NAME   TEAM
# 0     Abdulla, YA   KXIP
# 1    Abdur Razzak    RCB
# 2     Agarkar, AB    KKR
# 3       Ashwin, R    CSK
# 4    Badrinath, S    CSK
# ..            ...    ...
# 125     Yadav, AS     DC
# 126   Younis Khan     RR
# 127  Yuvraj Singh  KXIP+
# 128   Zaheer Khan    MI+
# 129    Zoysa, DNT     DC
#
# [130 rows x 2 columns]

# %%
a = df[['PLAYER NAME','COUNTRY','TEAM','PLAYING ROLE']].head()
a
# Out:
#     PLAYER NAME COUNTRY  TEAM PLAYING ROLE
# 0   Abdulla, YA      SA  KXIP   Allrounder
# 1  Abdur Razzak     BAN   RCB       Bowler
# 2   Agarkar, AB     IND   KKR       Bowler
# 3     Ashwin, R     IND   CSK       Bowler
# 4  Badrinath, S     IND   CSK      Batsman

# %%
df[5:10]       # Rows
# Out:
#    Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 5       6     Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6       7      Balaji, L    2     IND  CSK+       Bowler      51      27
# 7       8  Bollinger, DE    2     AUS   CSK       Bowler      54      50
# 8       9       Botha, J    2      SA    RR   Allrounder      83      17
# 9      10    Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 5         172     72.26  ...   95.45       0       0     0    0.00  0.00
# 6         120     78.94  ...   72.22       1    1342    52   25.81  7.98
# 7          50     92.59  ...  165.88       1     693    37   18.73  7.22
# 8         609     85.77  ...  114.73       3     610    19   32.11  6.85
# 9        4686     84.76  ...  127.51      13       0     0    0.00  0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df[0:5][["PLAYER NAME","AGE","COUNTRY"]]
# Out:
#     PLAYER NAME  AGE COUNTRY
# 0   Abdulla, YA    2      SA
# 1  Abdur Razzak    2     BAN
# 2   Agarkar, AB    2     IND
# 3     Ashwin, R    1     IND
# 4  Badrinath, S    2     IND

# %%
df[["PLAYER NAME","AGE","COUNTRY"]][0:5]
# Out:
#     PLAYER NAME  AGE COUNTRY
# 0   Abdulla, YA    2      SA
# 1  Abdur Razzak    2     BAN
# 2   Agarkar, AB    2     IND
# 3     Ashwin, R    1     IND
# 4  Badrinath, S    2     IND
